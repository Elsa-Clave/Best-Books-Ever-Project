# %% [markdown]
# #### Book Recommender 👁️‍🗨️

# %% [markdown]
# #### Libraries:

# %%
#Database management
import pandas as pd
import numpy as np
import datetime
pd.set_option('display.max_columns', None)

#Plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#Recommender System
import scipy
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %% [markdown]
# #### The main idea is 💡:
# Find similar books inside the same subset (by genre) to the book liked by the user
#
# - Create subsets by genres (as there are over 900 group them first in dictionaries)
# - Asking for user imput (what book do you like) if present in df
# - Trough KNN recommend a book based on imput
# - Adjust KNN model (hyperparameters, n_neighbors etc.)

# %% [markdown]
# #### Import the data:

# %%
best = pd.read_csv('Data/best_clean.csv')

# %%
best.shape
# Out:
# (52478, 29)

# %% [markdown]
# #### Create subsets by genres:

# %%
import ast
best['genres'] = best['genres'].apply(lambda x: ast.literal_eval(x))

#a set of all unique genres
unique_genres = set()
best['genres'].apply(unique_genres.update)

print(f"Number of unique genres: {len(unique_genres)}")
print(f"Unique genres: {unique_genres}")
# Out:
# Number of unique genres: 982
# Unique genres: {'Genetics', 'Womens Studies', 'Bangladesh', 'Belgium', 'Teachers', 'Childrens', 'Pre Raphaelite', 'M M F', 'Woodwork', 'Classics', 'Epic', 'Amish', 'Canada', 'Mystery', '12th Century', 'Prehistory', 'Wonder Woman', 'Science Fiction Romance', 'Georgian', 'Punk', 'Amazon', 'College', 'Irish Literature', 'Money', 'Atheism', 'Pakistan', 'Words', 'Drama', 'Harlequin Nocturne', 'Management', 'Ecology', 'Old Testament', 'Poverty', 'Urban Planning', 'Cross Dressing', 'Parenting', 'Vegetarian', 'Biblical Fiction', 'Islamism', 'Social Justice', 'Virtual Reality', 'Comic Book', 'United States', 'Journaling', 'Monsters', 'Victorian Romance', 'Growth Mindset', 'Cats', 'Georgian Romance', 'Alternate Universe', 'Programming', 'M M Paranormal', 'Airships', 'Art and Photography', 'Esoterica', 'Spirituality', 'Alternative Medicine', 'Harlequin Romance', 'Judaism', 'Fighters', 'Near Future', 'Nigeria', 'Figure Skating', 'Graphic Novels', 'Engineering', 'Soldiers', 'Mali', 'Military History', 'Labor', 'Cartography', 'Mormonism', 'Jokes', 'Judaica', 'Eastern Philosophy', 'Road Trip', 'LGBT', 'Disease', 'Ecclesiology', 'Whodunit', 'Surreal', 'Comics Bd', 'Music', 'Gamebooks', 'Futuristic', 'Cryptids', 'Baha I', 'Books About Books', 'Intelligent Design', 'Poetry', 'Novels', 'Finance', 'Epic Fantasy', 'Motorcycle', 'Mystery Thriller', 'Food History', 'M M Sports Romance', 'BDSM', 'Algebra', 'Civil War History', 'Fat Acceptance', 'Gender', 'Geometry', 'Muslims', 'Literary Fiction', 'Regency', 'Taxation', 'Quantum Mechanics', 'Information Science', 'Academia', '19th Century', 'Horse Racing', 'Gay', 'Christianity', 'Star Trek Original Series', 'Field Guides', 'Astrology', 'Shonen', 'Death', 'India', 'Horticulture', 'Mountaineering', 'Comic Strips', 'Gay Fiction', '1st Grade', 'Earth Sciences', 'Led Zeppelin', 'M F Romance', 'New Adult', 'Kazakhstan', 'Cozy Mystery', 'Russia', 'Romanian Literature', 'Paramedics', 'Unfinished', 'Civil War', 'Folk Tales', 'Design', 'Native American History', 'Japanese History', 'Visual Art', 'Christian', 'Humor', 'Marathi', 'Edwardian', 'M M Science Fiction', 'Divorce', 'Contemporary Romance', 'Royal Air Force', 'World Of Warcraft', 'Dc Comics', 'Reference', 'Spanish Literature', 'Plantagenet', 'Menage', 'Feminism', 'Futurism', 'Asexual', 'Museology', 'English Civil War', 'Basketball', 'Divination', 'Christian Contemporary Fiction', 'Political Science', 'Personal Finance', 'Middle Grade', 'Time Travel Romance', 'Maps', 'Communication', 'Heroic Fantasy', 'Harlequin Teen', 'Queer Lit', 'NSFW', 'Social Change', 'Witchcraft', 'Folklore', 'Christian Fantasy', 'Military Fiction', 'Language', 'Hip Hop', 'Nutrition', 'Harlequin Heartwarming', 'Artificial Intelligence', 'Social', 'Manga Romance', 'Harlequin Presents', 'Yeti', 'Essays', 'Crime', 'Linguistics', 'Young Readers', 'Cuisine', 'Literary Criticism', 'Graphic Novels Manga', 'Turkish Literature', 'Jewish', 'Victor Frankenstein', 'Research', 'Booze', 'Ethiopia', 'Ancient History', 'Gay For You', 'Illness', 'Post Colonial', 'Taoism', 'Seinen', 'Rwanda', 'Fantasy Of Manners', 'American Fiction', 'Ethnography', 'Travelogue', 'Theory', 'Israel', 'Doctors', 'Literature', 'Holiday', 'Battle Of Britain', 'Strippers', 'Mathematics', 'Pulp', 'Harlequin Desire', 'Society', 'Splatterpunk', 'Popular Science', 'Vampires', 'Omegaverse', 'Lebanon', 'Traditional Chinese Medicine', 'French Literature', 'Comix', 'Urban Studies', 'Sudan', 'Technical', 'Erotic Romance', 'Stories', 'True Crime', 'Mythology', 'Christian Fiction', 'Audiobook', 'Church', 'School Stories', 'Slash Fiction', 'Fractured Fairy Tales', 'History Of Medicine', 'Aliens', 'Memoir', 'Chick Lit', 'Rus', 'Lovecraftian', 'Warcraft', 'Aircraft', 'Coming Of Age', 'Short Stories', 'Beauty and The Beast', 'Adventure', 'Gastronomy', 'Comedy', 'Tanzania', 'Banks', 'Denmark', 'Halloween', 'Sequential Art', 'Butch Femme', 'Traditional Regency', 'Zen', 'Back To School', 'Mixed Martial Arts', 'Government', 'Wicca', 'Modern  ...

# %% [markdown]
# There are too many combinations of genres so It will better to try to simplyfy.
# The first step is to create a list of unique genres and then, the subsets

# %%
genre_subsets = {genre: best[best['genres'].apply(lambda x: genre in x)] for genre in unique_genres}

#number of books per genre
for genre, subset in genre_subsets.items():
    print(f'Genre: {genre}, number of books: {len(subset)}')
# Out:
# Genre: Genetics, number of books: 21
# Genre: Womens Studies, number of books: 43
# Genre: Bangladesh, number of books: 19
# Genre: Belgium, number of books: 41
# Genre: Teachers, number of books: 21
# Genre: Childrens, number of books: 5226
# Genre: Pre Raphaelite, number of books: 1
# Genre: M M F, number of books: 35
# Genre: Woodwork, number of books: 1
# Genre: Classics, number of books: 6902
# Genre: Epic, number of books: 567
# Genre: Amish, number of books: 73
# Genre: Canada, number of books: 528
# Genre: Business, number of books: 709
# Genre: Northern Africa, number of books: 3
# Genre: Harem, number of books: 8
# Genre: Norman, number of books: 1
# Genre: Magick, number of books: 28
# Genre: Algeria, number of books: 15
# Genre: African American Literature, number of books: 49
# Genre: Climate Change, number of books: 17
# Genre: Google, number of books: 3
# Genre: Students, number of books: 2
# Genre: Greece, number of books: 145
# Genre: Software, number of books: 20
# Genre: Goth, number of books: 3
# Genre: Stand Up, number of books: 2
# Genre: Botswana, number of books: 11
# Genre: Classical Music, number of books: 1
# Genre: London Underground, number of books: 1
# Genre: Germany, number of books: 360
# Genre: Mermaids, number of books: 100
# Genre: Womens Fiction, number of books: 376
# Genre: Computer Science, number of books: 55
# Genre: Vaccines, number of books: 2
# Genre: Health, number of books: 381
# Genre: Survival, number of books: 335
# Genre: Skepticism, number of books: 26
# Genre: Polyamorous, number of books: 1
# Genre: Architecture, number of books: 45
# Genre: Internet, number of books: 12
# Genre: Detective, number of books: 1015
# Genre: Loveswept, number of books: 4
# Genre: Go, number of books: 1
# Genre: Police, number of books: 94
# Genre: Semiotics, number of books: 5
# Genre: Kenya, number of books: 21
# Genre: Sierra Leone, number of books: 2
# Genre: Fairy Tale Retellings, number of books: 138
# Genre: Czech Literature, number of books: 79
# Genre: Love Story, number of books: 63
# Genre: Mysticism, number of books: 55
# Genre: Epic Poetry, number of books: 6
# Genre: Urban Fantasy, number of books: 3458
# Genre: Bicycles, number of books: 2
# Genre: Supernatural Romance, number of books: 1
# Genre: Republic Of The Congo, number of books: 3
# Genre: The Americas, number of books: 1
# Genre: Asian Literature, number of books: 282
# Genre: Crafts, number of books: 44
# Genre: 15th Century, number of books: 26
# Genre: Dutch Literature, number of books: 112

# %% [markdown]
# The discrepancy (52478 books in the dataframe vs #52,729 after subset creation) can be attributed to the fact that some books are categorized into multiple genres.
# This leads to overlapping counts when you create subsets based on individual genres. For example, if a book belongs to both "Literary Fiction" and "Romance," it will contribute to the count of books in both genre_subsets['Literary Fiction'] and genre_subsets['Romance'].

# %% [markdown]
# 👉In json (dictionary-like format) with the help of node.js all the genres have been assigned to more general groups in order to simplify the process

# %%
category_groups = {
  "Horror": [
    "Lovecraftian",
    "Cthulhu Mythos",
    "Horror",
    "Ghosts",
    "Demons",
    "Mary Shelley",
    "World Of Darkness",
    "Paranormal Mystery",
    "Noir",
    "Zombies",
    "Gothic Horror",
    "Ghost Stories",
    "Buffy The Vampire Slayer",
    "Gothic Romance",
    "Witches",
    "Cryptids",
    "Splatterpunk",
    "Victor Frankenstein",
    "Dark",
    "Monsters",
    "Halloween",
    "Supernatural"
  ],
  "Erotica": [
    "Erotic Romance",
    "BDSM",
    "Menage",
    "Erotic Paranormal Romance",
    "Erotic Horror",
    "Erotica",
    "Strippers",
    "Omegaverse",
    "Pornography",
    "NSFW",
    "Slash Fiction",
    "Lesbian Fiction",
    "M M M",
    "Yuri",
    "M M F",
    "Polyamorous",
    "M M Mystery",
    "Lesbian Romance",
    "M M Fantasy",
    "M F Romance",
    "Paranormal Romance",
    "Military Romance",
    "M M Contemporary",
    "African American Romance",
    "Swashbuckling",
    "Romantic",
    "Viking Romance",
    "Historical Romance",
    "Mills and Boon",
    "Love Inspired Historical",
    "Loveswept",
    "Georgian Romance",
    "M M Young Adult",
    "Young Adult",
    "M M Romance",
    "Medieval Romance",
    "Love Story",
    "Interracial Romance",
    "",
    "Harlequin Romance",
    "Love Inspired Suspense",
    "Lesbian Romance",
    "M F Romance",
    "New Adult Romance",
    "Regency Romance",
    "Harlequin Heartwarming",
    "Category Romance",
    "Traditional Regency",
    "Harlequin Blaze",
    "Harlequin Nocturne",
    "Harlequin",
    "Regency",
    "Western Romance",
    "Futuristic Romance",
    "Sports Romance",
    "Romantic Suspense",
    "Harlequin Desire"
  ],
  "Computer Science": [
    "Programming",
    "Coding",
    "Virtual Reality",
    "Mmorpg",
    "Computers",
    "Website Design",
    "Artificial Intelligence",
    "Software",
    "Algorithms",
    "Computer Science"
  ],
  "Psychology": [
    "Counselling",
    "Relationships",
    "Mental Illness",
    "Psychology",
    "Psychiatry",
    "Growth Mindset",
    "Emotion",
    "Gender and Sexuality",
    "Parenting",
    "Personal Development",
    "Mental Health",
    "Asexual"
  ],
  "Languages": [
    "Turkish",
    "Danish",
    "Language",
    "Linguistics"
  ],
  "Arts and Creativity": [
    "Design",
    "Colouring Books",
    "Gothic",
    "Street Art",
    "Graffiti",
    "Photography",
    "Architecture",
    "Visual Art",
    "Pre Raphaelite",
    "Picture Books",
    "Museums",
    "Sequential Art",
    "Art Design",
    "Woodwork",
    "Art and Photography",
    "Musicals",
    "Art History",
    "Jewellery",
    "Games",
    "Quilting",
    "Gardening",
    "Film",
    "Theatre",
    "Jazz",
    "Comedy",
    "Art",
    "Writing",
    "Crafts",
    "Drawing",
    "Surreal",
    "Comics Manga",
    "Comix"
  ],
  "Mystery": [
    "Mystery",
    "Suspense",
    "Occult",
    "Cozy Mystery",
    "Historical Mystery",
    "Mystery Thriller",
    "Murder Mystery",
    "Paranormal",
    "Spy Thriller",
    "Legal Thriller",
    "Whodunit",
    "Noir",
    "Ghost Stories",
    "Golden Age Mystery",
    "Detective",
    "Hard Boiled",
    "Deception"
  ],
  "Health": [
    "Emergency Services",
    "Fitness",
    "Alternative Medicine",
    "Vaccines",
    "Disease",
    "Health",
    "Food Preservation",
    "Paramedics",
    "Doctors",
    "Health Care",
    "Vegetarian",
    "Self Help",
    "Illness",
    "Vegan",
    "Naturopathy",
    "Diets",
    "Medical"
  ],
  "Crime": [
    "Crime",
    "Nordic Noir",
    "Pulp",
    "True Crime",
    "Conspiracy Theories",
    "Whodunit",
    "Noir",
    "Detective"
  ],
  "Sports": [
    "Basketball",
    "Mixed Martial Arts",
    "Martial Arts",
    "Racing",
    "Cycling",
    "Football",
    "Fighters",
    "Hockey",
    "Climbing"
  ],
  "Culture and Society": [
    "Social Justice",
    "Gay For You",
    "Plus Size",
    "Womens",
    "Adolescence",
    "Polygamy",
    "African American",
    "Road Trip",
    "Race",
    "Cultural Studies",
    "Communication",
    "Prostitution",
    "Fire Services",
    "LGBT",
    "Biography Memoir",
    "International Relations",
    "Poverty",
    "Food Writing",
    "Global Warming",
    "Bisexual",
    "Feminism",
    "Womens Studies",
    "Sexuality",
    "Alcohol",
    "Americana",
    "Far Right",
    "Leadership",
    "Oral History",
    "Marriage",
    "New York",
    "Social Media",
    "Outdoors",
    "Field Guides",
    "Book Club",
    "Holiday",
    "Queer",
    "Polyamory",
    "Gender",
    "Anti Intellectualism",
    "Slice Of Life",
    "Family",
    "Social Movements",
    "Social Work",
    "Multicultural Literature",
    "Adoption",
    "Cultural",
    "Society",
    "Fat Acceptance",
    "Southern",
    "Activism",
    "Sex Work",
    "Gender Studies",
    "Queer Lit",
    "Anarchism",
    "Social Science",
    "Anti Racist",
    "Female Authors",
    "Fat",
    "Transgender",
    "Fostering",
    "Social Issues"
  ],
  "Games": [
    "Video Games",
    "Gamebooks",
    "Choose Your Own Adventure"
  ],
  "Science Fiction": [
    "Military Science Fiction",
    "Cyberpunk",
    "Space Opera",
    "Space"
  ]
}

# %%
#there may be missing categories in the dictionary

# %% [markdown]
# After mapping, If a book's genres match multiple categories (for example, if a book has both 'Fantasy' and 'Romance' genres), the function will still only return the first matching category it finds.
# The function will return the first category where it finds a match between genres and group_genres.
# This means if a book has genres that match multiple categories, it will choose the first category that appears in category_groups where there is a match.

# %%
#Function to map genres to categories
def map_genres_to_category(genres, category_groups):
    for category, group_genres in category_groups.items():
        if any(genre in group_genres for genre in genres):
            return category
    return None

# %%
#Mapping genres to categories
best['category'] = best['genres'].apply(lambda x: map_genres_to_category(x, category_groups))

# %% [markdown]
# ### Preprocessing data

# %% [markdown]
# After many failed attempts that later will be included I realized there was a much needed cleaning process

# %%
#erase genres column
best.drop('genres', axis=1, inplace=True)

# %%
#rename column category to genre
best.rename(columns={'category': 'genre'}, inplace=True)

# %%
best['genre'].isnull().sum()
# Out:
# 5155

# %%
best['genre'].value_counts()
# Out:
# genre
# Non-Fiction and Others       12009
# Classics                      8931
# Literature by Region          8116
# Horror                        6902
# Erotica                       3105
# Fantasy                       3003
# Fiction                       1718
# Religion and Spirituality     1164
# Economy                        939
# Comic and Manga                255
# History                        238
# Nature and Animals             188
# Romance                        159
# World                          123
# Science                        105
# Arts and Creativity            101
# Psychology                      80
# Mystery                         75
# Culture and Society             44
# Health                          33
# Sports                          13
# Languages                        8
# Computer Science                 6
# Crime                            5
# Science Fiction                  3
# Name: count, dtype: int64

# %%
best['genre'].fillna(best['genre'].mode()[0], inplace=True)
# Out:
# C:\Users\Elsa\AppData\Local\Temp\ipykernel_1908\748924298.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   best['genre'].fillna(best['genre'].mode()[0], inplace=True)

# %%
best['genre'].isnull().sum()
# Out:
# 0

# %%
#unique genres
unique_genres = best['genre'].unique()
#subset of genres 
genre_subsets = {genre: best[best['genre'] == genre] for genre in unique_genres}

# %%
#number of books in each subset
for genre, subset in genre_subsets.items():
    print(f"{genre}: {len(subset)}")
# Out:
# Non-Fiction and Others: 17164
# Classics: 8931
# Horror: 6902
# Literature by Region: 8116
# Fantasy: 3003
# Economy: 939
# Erotica: 3105
# Fiction: 1718
# Religion and Spirituality: 1164
# Psychology: 80
# Comic and Manga: 255
# Culture and Society: 44
# World: 123
# Science: 105
# Arts and Creativity: 101
# History: 238
# Nature and Animals: 188
# Romance: 159
# Mystery: 75
# Sports: 13
# Computer Science: 6
# Health: 33
# Crime: 5
# Languages: 8
# Science Fiction: 3

# %%
# Check for duplicates based on isbn (unique code)
duplicate_isbn = best[best.duplicated(subset=['isbn'], keep=False)]
print(duplicate_isbn)
# Out:
#                                                   bookid  \
# 2                             2657.To_Kill_a_Mockingbird
# 3                               1885.Pride_and_Prejudice
# 7                         11127.The_Chronicles_of_Narnia
# 10                       11870085-the-fault-in-our-stars
# 11           386162.The_Hitchhiker_s_Guide_to_the_Galaxy
# ...                                                  ...
# 52407  2823038-forever-young-forever-free-forever-you...
# 52416                               23014216-when-i-fall
# 52417                                    26158233-aideen
# 52420                            25313988-spelarens-sten
# 52474                                   11836711-anasazi
#
#                                                    title  \
# 2                                  To Kill a Mockingbird
# 3                                    Pride and Prejudice
# 7                               The Chronicles of Narnia
# 10                                The Fault in Our Stars
# 11                  The Hitchhiker's Guide to the Galaxy
# ...                                                  ...
# 52407  Forever Young, Forever Free Forever Young, For...
# 52416                                        When I Fall
# 52417                                             Aideen
# 52420                                     Spelarens sten
# 52474                                            Anasazi
#
#                                                   series  \
# 2                                  To Kill a Mockingbird
# 3                                   Not part of a series
# 7      The Chronicles of Narnia (Publication Order) #1–7
# 10                                  Not part of a series
# 11               The Hitchhiker's Guide to the Galaxy #1
# ...                                                  ...
# 52407                               Not part of a series
# 52416                                  Alabama Summer #3
# 52417                               Slater Brothers #3.5
# 52420                               Not part of a series
# 52474                                  Sense of Truth #2
#
#                                           author  rating  \
# 2                                     Harper Lee    4.28
# 3      Jane Austen, Anna Quindlen (Introduction)    4.26
# 7       C.S. Lewis, Pauline Baynes (Illustrator)    4.26
# 10                 John Green (Goodreads Author)    4.21
# 11                                 Douglas Adams    4.22
# ...                                          ...     ...
# 52407                               Hettie Jones    3.67
# 52416              J. Daniels (Goodreads Author)    4.30
# 52417              L.A. Casey (Goodreads Author)    4.37
# 52420                             Bruno K. Öijer    3.60
# 52474                              Emma Michaels    4.19
#
#                                              description language  \
# 2      The unforgettable novel of a childhood in a sl...  English
# 3      Alternate cover edition of ISBN 9780679783268S...  English
# 7      Journeys to the end of the world, fantastic cr...  English
# 10     Despite the tumor-shrinking medical miracle th...  English
# 11     Seconds before the Earth is demolished to make...  English
# ...                                                  ...      ...
# 52407                                            Unknown  Unknown
# 52416  From New York Times bestselling author, J. Dan...  Unknown
# 52417  Aideen Collins is fed up. She is at her wits’ ...  English
# 52420                                            Unknown  Swedish
# 52474  'Anasazi', sequel to 'The Thirteenth Chime' by...  English
#
#                 isbn                                         characters  \
# 2      9999999999999  ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...
# 3      9999999999999  ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...
# 7      9999999999999  ['Polly', 'Aslan', 'Lucy Pevensie', 'Edmund Pe...
# 10     9999999999999  ['Hazel Grace Lancaster', 'Augustus Waters', '...
# 11     9999999999999  ['Zaphod Beeblebrox', 'Arthur Dent', 'Ford Pre...
# ...              ...                                                ...
# 52407  9999999999999                                                 []
# 52416  9999999999999                    ['Reed Tennyson', 'Beth Davis']
# 52417  9999999999999                  ['Kane Slater', 'Aideen Collins']
# 52420  9999999999999                                                 []
# 52474  9999999999999                                                 []
#
#       bookformat                             edition  pages  \
# 2      Paperback                             Unknown    324
# 3      Paperback  Modern Library Classics, USA / CAN    279
# 7      Paperback                     Reissue Edition    767
# 10     Hardcover                             Unknown    313
# 11     Paperback                             Unknown    193
# ...          ...                                 ...    ...
# 52407  Paperback                             Unknown      0
# 52416    Unknown                             Unknown    343
# 52417      ebook                             Unknown    151
# 52420  Paperback                             Unknown     50
# 52474  Paperback                       First Edition    190
#
#                               publisher publishdate firstpublishdate  \
# 2      Harper Perennial Modern Classics  2006-05-23       2060-07-11
# 3                        Modern Library  2000-10-10       2013-01-28
# 7                         HarperCollins  2002-09-16       2056-10-28
# 10                         Dutton Books  2012-01-10              NaN
# 11                              Del Rey  2007-06-23       1979-10-12
# ...                                 ...         ...              ...
# 52407                           Unknown         NaN              NaN
# 52416                           Unknown  2015-03-17              NaN
# 52417                        L.A. Casey  2015-11-03              NaN
# 52420                           Unknown  1979-01-01              NaN
# 52474                Bokheim Publishing  2011-08-05       2011-08-03
#
#                                                   awards  numratings  \
# 2      ['Pulitzer Prize for Fiction (1961)', 'Audie A...     4501075
# 3                                                     []     2998241
# 7                                                     []      517740
# 10     ['Georgia Peach Book Award (2013)', 'Buxtehude...     3550714
# 11                                                    []     1436325
# ...                                                  ...         ...
# 52407                                                 []           3
# 52416                                                 []       12022
# 52417                                                 []        5916
# 52420                                                 []           5
# 52474                                                 []          37
#
#        likedpercent                                            setting  \
# 2         95.000000               ['Maycomb, Alabama (United States)']
# 3         94.000000  ['United Kingdom', 'Derbyshire, England (Unite...
# 7         96.000000                                ['London, England']
# 10        93.000000  ['Indianapolis, Indiana (United States)', 'Ams...
# 11        94.000000                                                 []
# ...             ...                                                ...
# 52407     92.231545                                                 []
# 52416     97.000000                ['Ruxton, Alabama (United States)']
# 52417     97.000000                                                 []
# 52420    100.000000                                                 []
# 52474     95.000000                                                 []
#
#                                                 coverimg  bbescore  bbevotes  \
# 2      https://i.gr-assets.com/images/S/compressed.ph...   2269402     23328
# 3      https://i.gr-assets.com/images/S/compressed.ph...   1983116     20452
# 7      https://i.gr-assets.com/images/S/compressed.ph...   1238556     12949
# 10     https://i.gr-assets.com/images/S/compressed.ph...   1087056     11287
# 11     https://i.gr-assets.com/images/S/compressed.ph...   1063601     10996
# ...                                                  ...       ...       ...
# 52407                                 No cover available         2         1
# 52416  https://i.gr-assets.com/images/S/compressed.ph...         2         1
# 52417  https://i.gr-assets.com/images/S/compressed.ph...         2         1
# 52420  https://i.gr-assets.com/images/S/compressed.ph...         2         1
# 52474  https://i.gr-assets.com/images/S/compressed.ph...         0         1
#
#        price   5_star   4_star  3_star  2_star  1_star                   genre
# 2        0.0  2363896  1333153  573280  149952   80794                Classics
# 3        0.0  1617567   816659  373311  113934   76770                Classics
# 7        0.0   254964   167572   74362   15423    5419                Classics
# 10       0.0  1784471  1022406  512574  150365   80898  Non-Fiction and Others
# 11       0.0   725771   420864  199846   58326   31518                Classics
# ...      ...      ...      ...     ...     ...     ...                     ...
# 52407    0.0        0        0       0       0       0  Non-Fiction and Others
# 52416    0.0     5939     4225    1488     256     114                 Erotica
# 52417    0.0     3322     1704     695     150      45                Classics
# 52420    0.0        1        1       3       0       0  Non-Fiction and Others
# 52474    0.0       16       14       5       2       0                 Romance
#
# [4460 rows x 29 columns]

# %%
#based on title
duplicate_title = best[best.duplicated(subset=['title'], keep=False)]
print(duplicate_title)
# Out:
#                        bookid          title                     series  \
# 4              41865.Twilight       Twilight       The Twilight Saga #1
# 6          170448.Animal_Farm    Animal Farm       Not part of a series
# 18            10210.Jane_Eyre      Jane Eyre       Not part of a series
# 24     18144590-the-alchemist  The Alchemist       Not part of a series
# 28       256683.City_of_Bones  City of Bones  The Mortal Instruments #1
# ...                       ...            ...                        ...
# 52471      12464361-elemental      Elemental          Soul Guardians #2
# 52472   12395883-unbelievable   Unbelievable               Port Fare #2
# 52473      11492014-fractured      Fractured                 Fateful #2
# 52475         10815662-marked         Marked          Soul Guardians #1
# 52476    11330278-wayward-son    Wayward Son       Not part of a series
#
#                                                   author  rating  \
# 4                                        Stephenie Meyer    3.60
# 6      George Orwell, Russell Baker (Preface), C.M. W...    3.95
# 18     Charlotte Brontë, Michael Mason (Editor), Barn...    4.13
# 24     Paulo Coelho (Goodreads Author), Alan R. Clark...    3.88
# 28                    Cassandra Clare (Goodreads Author)    4.10
# ...                                                  ...     ...
# 52471                  Kim Richardson (Goodreads Author)    4.07
# 52472                   Sherry Gammon (Goodreads Author)    4.16
# 52473                   Cheri Schmidt (Goodreads Author)    4.00
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
#
#                                              description language  \
# 4      About three things I was absolutely positive.\...  English
# 6      Librarian's note: There is an Alternate Cover ...  English
# 18     Orphaned as a child, Jane has felt an outcast ...  English
# 24     Paulo Coelho's enchanting novel has inspired a...  English
# 28     When fifteen-year-old Clary Fray heads out to ...  English
# ...                                                  ...      ...
# 52471  When seventeen-year-old Kara Nightingale is su...  English
# 52472  Lilah Lopez Dreser's in town to take care of u...  English
# 52473  The Fateful Trilogy continues with Fractured. ...  English
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  English
# 52476  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  English
#
#                 isbn                                         characters  \
# 4      9780316015844  ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...
# 6      9780451526342  ['Snowball', 'Napoleon', 'Clover', 'Boxer', 'O...
# 18     9780142437209  ['Jane Eyre', 'Bertha Mason', 'Grace Poole', '...
# 24     9780062315007           ['Santiago', 'Alchemist', 'Melchizedek']
# 28     9781416914280  ['Alexander "Alec" Lightwood', 'Jonathan "Jace...
# ...              ...                                                ...
# 52471     B005IGOSCC                                                 []
# 52472  9781477594247                                                 []
# 52473  2940012616562                                                 []
# 52475  9781461017097                                                 []
# 52476  9781450755634                                                 []
#
#                   bookformat                   edition  pages  \
# 4                  Paperback                   Unknown    501
# 6      Mass Market Paperback                   Unknown    141
# 18                 Paperback          Penguin Classics    532
# 24                 Paperback  25th Anniversary Edition    182
# 28                 Hardcover                   Unknown    485
# ...                      ...                       ...    ...
# 52471         Kindle Edition                   Unknown    151
# 52472              Paperback                   Unknown    360
# 52473                   Nook                   Unknown      0
# 52475              Paperback                   Unknown    280
# 52476              Paperback               1st edition    507
#
#                          publisher publishdate firstpublishdate  \
# 4        Little, Brown and Company  2006-09-06       2005-10-05
# 6                  Signet Classics  1996-04-28       2045-08-17
# 18                         Penguin  2003-02-04       2047-10-16
# 24                       HarperOne  2014-04-15       1988-10-28
# 28     Margaret K. McElderry Books  2007-03-27              NaN
# ...                            ...         ...              ...
# 52471               Kim Richardson  2011-08-21       2011-08-01
# 52472      Wordpaintings Unlimited  2013-04-11       2013-03-30
# 52473                Cheri Schmidt  2011-05-28              NaN
# 52475                  CreateSpace  2011-03-18       2011-03-15
# 52476          Cascada Productions  2011-09-01       2011-04-05
#
#                                                   awards  numratings  \
# 4      ['Georgia Peach Book Award (2007)', 'Buxtehude...     4964519
# 6      ['Prometheus Hall of Fame Award (2011)', 'Retr...     2740713
# 18                                                    []     1624682
# 24     ['NBDB National Book Award Nominee for Transla...     2107732
# 28     ['Locus Award Nominee for Best First Novel (20...     1617465
# ...                                                  ...         ...
# 52471                                                 []        1947
# 52472                                                 []        1028
# 52473                                                 []         871
# 52475            ["Readers' Favorite Book Award (2011)"]        6674
# 52476                                                 []         238
#
#        likedpercent                                            setting  \
# 4              78.0  ['Forks, Washington (United States)', 'Phoenix...
# 6              91.0                      ['England', 'United Kingdom']
# 18             93.0                          ['Thornfield', 'England']
# 24             87.0  ['Egypt', 'Sahara Desert', 'Tangier (Morocco)'...
# 28             92.0        ['New York City, New York (United States)']
# ...             ...                                                ...
# 52471          94.0                                                 []
# 52472          94.0            ['Port Fare, New York (United States)']
# 52473          94.0                                                 []
# 52475          84.0                                                 []
# 52476          90.0                                                 []
#
#                                                 coverimg  bbescore  bbevotes  \
# 4      https://i.gr-assets.com/images/S/compressed.ph...   1459448     14874
# 6      https://i.gr-assets.com/images/S/compressed.ph...   1276599     13264
# 18     https://i.gr-assets.com/images/S/compressed.ph...    826759      8740
# 24     https://i.gr-assets.com/images/S/compressed.ph...    765587      8008
# 28     https://i.gr-assets.com/images/S/compressed.ph...    721821      7601
# ...                                                  ...       ...       ...
# 52471  https://i.gr-assets.com/images/S/compressed.ph...         0         1
# 52472  https://i.gr-assets.com/images/S/compressed.ph...         0         1
# 52473  https://i.gr-assets.com/images/S/compressed.ph...         0         1
# 52475  https://i.gr-assets.com/images/S/compressed.ph...         0         1
# 52476  https://i.gr-assets.com/images/S/compressed.ph...         0         1
#
#         price   5_star   4_star   3_star  2_star  1_star     genre
# 4        21.0  1751460  1113682  1008686  542017  548674    Horror
# 6       442.0   986764   958699   545475  165093   84682  Classics
# 18      546.0   746070   501478   256972   76970   43192  Classics
# 24     1322.0   805221   613564   414410  172160  102377  Classics
# 28      629.0   745774   465337   271968   87611   46775    Horror
# ...       ...      ...      ...      ...     ...     ...       ...
# 52471     0.0      801      636      391      84      35    Horror
# 52472  1918.0      442      384      142      48      12   Fiction
# 52473     0.0      311      310      197      42      11   Fantasy
# 52475   737.0     2109     1868     1660     647     390    Horror
# 52476   286.0       77       78       59      19       5  Classics
#
# [4218 rows x 29 columns]

# %% [markdown]
# It's possible for different books (different isbn) to have the same title. For example, books with different editions or translations may share the same title but have unique ISBNs.
# Conversely, books with the same ISBN might have different titles (e.g., different editions with slightly modified titles).

# %%
duplicate_rows = best[best.duplicated(keep=False)]
print(duplicate_rows)
# Out:
#                                                 bookid  \
# 37377                         8794263-promises-to-keep
# 37378                                    1909590.Click
# 37379               23394408-die-unendlichkeit-schl-ft
# 37380                               7544945-death-note
# 37381                                25886017-m-scaras
# ...                                                ...
# 37480                              26845691-beatlebone
# 37481              22916606-gli-enigmi-dei-vedovi-neri
# 37482                                       13571757-1
# 37381    159                   Unknown  1988-05-01       1988-01-01
# ...      ...                       ...         ...              ...
# 37480    263                 Canongate  2015-10-29              NaN
# 37481    288                   Rizzoli  1990-10-01       1990-01-06
# 37482    184                  Shueisha  2011-04-13              NaN
# 37483      0            Whitaker House  2005-02-01       1977-06-06
# 37484    160              urban comics  2015-10-02       2015-09-24
#
#                                                   awards  numratings  \
# 37377                                                 []        1997
# 37378  ['Deutscher Jugendliteraturpreis Nominee for J...        1910
# 37379                                                 []           2
# 37380                                                 []        5849
# 37381                                                 []          77
# ...                                                  ...         ...
# 37480                        ['Goldsmiths Prize (2015)']        2528
# 37481                                                 []         571
# 37482                                                 []       16361
# 37483                                                 []         333
# 37484                                                 []        9285
#
#        likedpercent                                            setting  \
# 37377     95.000000                       ['Illinois (United States)']
# 37378     86.000000                                                 []
# 37379     92.231545                                                 []
# 37380     99.000000                                                 []
# 37381     81.000000                                                 []
# ...             ...                                                ...
# 37480     81.000000                                                 []
# 37481     96.000000                                                 []
# 37482     96.000000                                                 []
# 37483     96.000000                                                 []
# 37484     93.000000  ['San Francisco, California (United States)', ...
#
#                                                 coverimg  bbescore  bbevotes  \
# 37377  https://i.gr-assets.com/images/S/compressed.ph...        87         1
# 37378  https://i.gr-assets.com/images/S/compressed.ph...        87         1
# 37379  https://i.gr-assets.com/images/S/compressed.ph...        87         1
# 37380  https://i.gr-assets.com/images/S/compressed.ph...        87         1
# 37381  https://i.gr-assets.com/images/S/compressed.ph...        87         1
# ...                                                  ...       ...       ...
# 37480  https://i.gr-assets.com/images/S/compressed.ph...        87         1
# 37481  https://i.gr-assets.com/images/S/compressed.ph...        87         1
# 37482  https://i.gr-assets.com/images/S/compressed.ph...        87         1
# 37483  https://i.gr-assets.com/images/S/compressed.ph...        87         1
# 37484  https://i.gr-assets.com/images/S/compressed.ph...        87         1
#
#         price  5_star  4_star  3_star  2_star  1_star  \
# 37377   423.0     582     833     476      84      22
# 37378   260.0     340     647     664     214      45
# 37379     0.0       0       0       0       0       0
# 37380  1200.0    3339    2045     408      44      13
# 37381   616.0      17      22      23      12       3
# ...       ...     ...     ...     ...     ...     ...
# 37480   416.0     471     860     729     334     134
# 37481  2599.0     166     243     137      21       4
# 37482  1330.0    9121    4447    2102     451     240
# 37483   500.0     206      83      31      11       2
# 37484  1289.0    2944    3791    1920     478     152
#
#                            genre
# 37377                   Classics
# 37378                    Fiction
# 37379     Non-Fiction and Others
# 37380                     Horror
# 37381                   Classics
# ...                          ...
# 37480       Literature by Region
# 37481     Non-Fiction and Others
# 37482            Comic and Manga
# 37483  Religion and Spirituality
# 37484     Non-Fiction and Others
#
# [100 rows x 29 columns]

# %%
# Drop duplicates based on all columns
best_no_duplicates = best.drop_duplicates()

print("Original DataFrame shape:", best.shape)
print("DataFrame shape after dropping duplicates:", best_no_duplicates.shape)
# Out:
# Original DataFrame shape: (52478, 29)
# DataFrame shape after dropping duplicates: (52428, 29)

# %% [markdown]
# ### First attempts of KNN model recommender

# %%
'''#Selecting the features to be used in the model
features = ['rating', 'pages','likedpercent','category','price','author','bbescore']
df_features = best[features]

#convert categorical to numerical (one hot encoding)
df_features = pd.get_dummies(df_features, columns=['category','author'])'''
# Out:
# "#Selecting the features to be used in the model\nfeatures = ['rating', 'pages','likedpercent','category','price','author','bbescore']\ndf_features = best[features]\n\n#convert categorical to numerical (one hot encoding)\ndf_features = pd.get_dummies(df_features, columns=['category','author'])"

# %%
'''numerical_features = ['rating', 'pages','likedpercent','price','bbescore']

#Standardization
scaler = StandardScaler()
df_features[numerical_features] = scaler.fit_transform(df_features[numerical_features])'''
# Out:
# "numerical_features = ['rating', 'pages','likedpercent','price','bbescore']\n\n#Standardization\nscaler = StandardScaler()\ndf_features[numerical_features] = scaler.fit_transform(df_features[numerical_features])"

# %%
'''#Let's train the model and after and ajdust and optimize the parameters later
knn = NearestNeighbors(n_neighbors=5, algorithm='auto').fit(df_features)'''
# Out:
# "#Let's train the model and after and ajdust and optimize the parameters later\nknn = NearestNeighbors(n_neighbors=5, algorithm='auto').fit(df_features)"

# %% [markdown]
# I get the error MemoryError error indicates that your system does not have enough RAM to handle the size of the array you are trying to create. So let's try a PCA (dimensionality reduction technique): to reduce the number of features.

# %%
'''from sklearn.decomposition import PCA
pca = PCA(n_components=50)
df_features_reduced = pca.fit_transform(df_features)'''
# Out:
# 'from sklearn.decomposition import PCA\npca = PCA(n_components=50)\ndf_features_reduced = pca.fit_transform(df_features)'

# %% [markdown]
# Again MemoryError: Unable to allocate 11.0 GiB for an array with shape (28227, 52478) and data type float64

# %%
'''#Let's try reducing features
#Selecting the features to be used in the model
features = ['rating','likedpercent','category','price','author']
df_features = best[features]

#convert categorical to numerical (one hot encoding)
df_features = pd.get_dummies(df_features, columns=['category','author'])'''
# Out:
# "#Let's try reducing features\n#Selecting the features to be used in the model\nfeatures = ['rating','likedpercent','category','price','author']\ndf_features = best[features]\n\n#convert categorical to numerical (one hot encoding)\ndf_features = pd.get_dummies(df_features, columns=['category','author'])"

# %%
'''numerical_features = ['rating','likedpercent','price']

#Standardization
scaler = StandardScaler()
df_features[numerical_features] = scaler.fit_transform(df_features[numerical_features])'''
# Out:
# "numerical_features = ['rating','likedpercent','price']\n\n#Standardization\nscaler = StandardScaler()\ndf_features[numerical_features] = scaler.fit_transform(df_features[numerical_features])"

# %%
'''knn = NearestNeighbors(n_neighbors=5, algorithm='auto').fit(df_features)'''
# Out:
# "knn = NearestNeighbors(n_neighbors=5, algorithm='auto').fit(df_features)"

# %% [markdown]
# Same error. Let's try another approach
# Preprocessing pipeline: to handle textual and numerical features efficiently. Then I'll apply KNN on each genre subset.

# %%
'''#Make sure there are no missing values
best['description'] = best['description'].fillna('No description available')

#Create subsets for each category
genre_subsets = {genre: best[best['category'] == genre] for genre in best['category'].unique()}'''
# Out:
# "#Make sure there are no missing values\nbest['description'] = best['description'].fillna('No description available')\n\n#Create subsets for each category\ngenre_subsets = {genre: best[best['category'] == genre] for genre in best['category'].unique()}"

# %% [markdown]
# Definition of the Preprocessing Pipeline:
# TfidfVectorizer for the description column.
# Imputation and normalization for numerical characteristics (rating, pages, numratings, likedpercent, price).

# %% [markdown]
# Then, transform each genre subset using the defined pipeline:

# %%
'''#Pre-process subsets
processed_subsets = {genre: preprocessor.fit_transform(subset) for genre, subset in genre_subsets.items()}'''
# Out:
# '#Pre-process subsets\nprocessed_subsets = {genre: preprocessor.fit_transform(subset) for genre, subset in genre_subsets.items()}'

# %%
'''#Define knn models for each genre subset
#knn_models = {genre: NearestNeighbors(n_neighbors=5, algorithm='auto').fit(features) for genre, features in processed_subsets.items()}'''
# Out:
# "#Define knn models for each genre subset\n#knn_models = {genre: NearestNeighbors(n_neighbors=5, algorithm='auto').fit(features) for genre, features in processed_subsets.items()}"

# %%
'''#define vectorizer
vectorizer = TfidfVectorizer(stop_words='english')
vectorizer.fit(best['description'])'''
# Out:
# "#define vectorizer\nvectorizer = TfidfVectorizer(stop_words='english')\nvectorizer.fit(best['description'])"

# %%
'''#Crear un índice KNN para cada subset de género
knn_models = {genre: NearestNeighbors(n_neighbors=5, algorithm='auto').fit(features)
              for genre, (features, _) in processed_subsets.items()}'''
# Out:
# "#Crear un índice KNN para cada subset de género\nknn_models = {genre: NearestNeighbors(n_neighbors=5, algorithm='auto').fit(features)\n              for genre, (features, _) in processed_subsets.items()}"

# %% [markdown]
# I tried many variations of this pipeline approach but got all kinds of errors

# %% [markdown]
# Almost everytime I got this problem:
# A mismatch between the number of features in the input data (X) and what the NearestNeighbors model expected.
# Because the input data (X) provided to the NearestNeighbors model does not match the dimensions that the model was trained on.
#
# After some debugging statments, they indicated that each genre subset (processed_features) had a different number of features, which aligns with the error message.

# %% [markdown]
# #### Final approach:

# %%
#Fill missing values

best['description'] = best['description'].fillna('No description available')
#best['genre'] = best['genre'].fillna('Unknown') (already done)
best['rating'] = best['rating'].fillna(best['rating'].mean())
best['pages'] = best['pages'].fillna(best['pages'].mean())
best['numratings'] = best['numratings'].fillna(best['numratings'].mean())
best['likedpercent'] = best['likedpercent'].fillna(best['likedpercent'].mean())
best['price'] = best['price'].fillna(best['price'].mean())

# %%
#Create subsets by genre (already done some cells above)
'''genre_subsets = {genre: best[best['genre'] == genre] for genre in best['genre'].unique()}'''
# Out:
# "genre_subsets = {genre: best[best['genre'] == genre] for genre in best['genre'].unique()}"

# %% [markdown]
# In this part:
# A ``TfidfVectorizer`` is created to convert text descriptions (from column 'description') into numerical vectors.
#
# A ``ColumnTransformer`` is defined that applies:
# ``TfidfVectorizer`` to the 'description' column.
# A Pipeline that first imputes missing values ​​with ``SimpleImputer`` and then scales the numeric data with ``StandardScaler`` to the numeric columns.
# The preprocessor wraps around the entire dataframe to ensure that all transformations are consistent.(This is extremely important)

# %%
#Define vectorizer 
vectorizer = TfidfVectorizer(stop_words='english')

#Define pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('desc', vectorizer, 'description'),
        ('num', Pipeline(steps=[
            ('impute', SimpleImputer(strategy='mean')),
            ('scale', StandardScaler())
        ]), ['rating', 'pages', 'numratings', 'likedpercent', 'price'])
    ])

#Fit preprocessor
preprocessor.fit(best)
# Out:
# ColumnTransformer(transformers=[('desc', TfidfVectorizer(stop_words='english'),
#                                  'description'),
#                                 ('num',
#                                  Pipeline(steps=[('impute', SimpleImputer()),
#                                                  ('scale', StandardScaler())]),
#                                  ['rating', 'pages', 'numratings',
#                                   'likedpercent', 'price'])])

# %% [markdown]
# Next:
# The preprocessor is applied to each genre subset, transforming the data into numerical characteristics.
#
# The transformed data is stored along with the original subset in processed_subsets.
# A KNN model is fit for each gender subset using the transformed characteristics.

# %%
#Apply the preprocessor to each subset
processed_subsets = {}
for genre, subset in genre_subsets.items():
    processed_features = preprocessor.transform(subset)
    processed_subsets[genre] = (processed_features, subset)

#Create a dictionary of knn models
knn_models = {genre: NearestNeighbors(n_neighbors=5, algorithm='auto').fit(features)
              for genre, (features, _) in processed_subsets.items()}

# %% [markdown]
# THE FUNCTION:
# - It searches for books whose title contains the first letters provided by the user (with an input)
# - If it finds a match (the match is in de dataset), it prompts the user to confirm the correct book.
# - If the book belongs to a genre with a KNN model and preprocessed data, it transforms the book features and uses KNN to find similar books.
# - Finally Returns a list of recommended titles based on the closest books.

# %%
#I may add a feature where it opens up the url with the book cover

# %%
#Function to recommend books!

def recommend_books(book_title, df, knn_models, processed_subsets, preprocessor):
    #Find matching books
    matching_books = df[df['title'].str.contains(book_title, case=False, na=False)]
    
    if matching_books.empty:
        return "Lo siento, este libro no lo tenemos. Prueba otro."

    #Confirm book with user
    for i, row in matching_books.iterrows():
        user_confirmation = input(f"¿Es '{row['title']}' el libro que te gusta? (escribe 'yes' o 'si' para confirmar): ")
        if user_confirmation.lower() in ['yes', 'si']:
            book = row
            genre = book['genre']
            
            #verify if the genre of the book has a KNN model and a preprocessor
            if genre not in knn_models or genre not in processed_subsets:
                return f"No se pudo procesar el género {genre}."

            processed_features, subset = processed_subsets[genre]
            
            #Preprocess book features using the corresponding tuned preprocessor
            book_features = preprocessor.transform(pd.DataFrame([book]))
            
            #Find similar books using KNN and genre
            knn_model = knn_models[genre]
            distances, indices = knn_model.kneighbors(book_features, n_neighbors=5)
            
            #Get the titles
            recommended_books = subset.iloc[indices[0]]['title'].tolist()
            #books_url= subset.iloc[indices[0]]['url'].tolist()
            return recommended_books #,books_url
    
    return "No se confirmó ningún libro. Por favor, inténtalo de nuevo."

# %% [markdown]
# Finally:
# Asks the user for the first letters of the title of the book they like.
# Call recommend_books with the given book title.
# Prints recommendations based on the specified book.

# %%
#Ask for user input
user_book = input("Introduce las primeras letras del título del libro que te gusta: ")
recommendations = recommend_books(user_book, best, knn_models, processed_subsets, preprocessor)
print(f"Recomendaciones para '{user_book}': {recommendations}")
#for i in urls:
#    print(open.image(i)) urllib
# Out:
# Recomendaciones para 'pride': ['Pride and Prejudice', 'The Hobbit, or There and Back Again', '1984', 'Harry Potter and the Prisoner of Azkaban', 'The Diary of a Young Girl']

# %%
#adding the IMAGE feature with Ipython.display

# %%
from IPython.display import Image, display

def recommend_books(book_title, df, knn_models, processed_subsets, preprocessor):
    # Find matching books
    matching_books = df[df['title'].str.contains(book_title, case=False, na=False)]
    
    if matching_books.empty:
        return "Lo siento, este libro no lo tenemos. Prueba otro."

    # Confirm book with user
    for i, row in matching_books.iterrows():
        user_confirmation = input(f"¿Es '{row['title']}' el libro que te gusta? (escribe 'yes' o 'si' para confirmar): ")
        if user_confirmation.lower() in ['yes', 'si']:
            book = row
            genre = book['genre']
            
            # Verify if the genre of the book has a KNN model and a preprocessor
            if genre not in knn_models or genre not in processed_subsets:
                return f"No se pudo procesar el género {genre}."

            processed_features, subset = processed_subsets[genre]
            
            # Preprocess book features using the corresponding tuned preprocessor
            book_features = preprocessor.transform(pd.DataFrame([book]))
            
            # Find similar books using KNN and genre
            knn_model = knn_models[genre]
            distances, indices = knn_model.kneighbors(book_features, n_neighbors=5)
            
            # Get the titles and URLs of the recommended books
            recommended_books = subset.iloc[indices[0]][['title', 'coverimg']].to_dict('records')
            
            # Display recommended books and their cover images
            for book in recommended_books:
                print(f"Recomendado: {book['title']}")
                display(Image(book['coverimg'],width=300, height=600))
            
            return recommended_books
    
    return "No se confirmó ningún libro. Por favor, inténtalo de nuevo."

# %%
# Ask for user input
user_book = input("Introduce las primeras letras del título del libro que te gusta: ")
print(f"Tu busqueda ha sido: '{user_book}' y sus recomendaciones:")
recommendations = recommend_books(user_book, best, knn_models, processed_subsets, preprocessor)
# Out:
# Tu busqueda ha sido: 'pride' y sus recomendaciones:
# Recomendado: Pride and Prejudice
# Recomendado: The Hobbit, or There and Back Again
# Recomendado: 1984
# Recomendado: Harry Potter and the Prisoner of Azkaban
# Recomendado: The Diary of a Young Girl

# %%
from IPython.display import Image, display


def recommend_books(book_title, df, knn_models, processed_subsets, preprocessor):
    # Find matching books
    matching_books = df[df['title'].str.contains(book_title, case=False, na=False)]
    
    if matching_books.empty:
        return "Lo siento, este libro no lo tenemos. Prueba otro."

    # Confirm book with user
    for i, row in matching_books.iterrows():
        user_confirmation = input(f"¿Es '{row['title']}' el libro que te gusta? (escribe 'yes' o 'si' para confirmar): ")
        if user_confirmation.lower() in ['yes', 'si']:
            book = row
            genre = book['genre']
            
            # Verify if the genre of the book has a KNN model and a preprocessor
            if genre not in knn_models or genre not in processed_subsets:
                return f"No se pudo procesar el género {genre}."

            processed_features, subset = processed_subsets[genre]
            
            # Preprocess book features using the corresponding tuned preprocessor
            book_features = preprocessor.transform(pd.DataFrame([book]))
            
            # Find similar books using KNN and genre
            knn_model = knn_models[genre]
            distances, indices = knn_model.kneighbors(book_features, n_neighbors=5)
            
            # Get the titles and URLs of the recommended books
            recommended_books = subset.iloc[indices[0]][['title', 'coverimg']].to_dict('records')
            
            # Display the first book as the confirmed one and others as recommended
            first_book = True
            for book in recommended_books:
                if first_book:
                    print(f"Este es tu libro: {book['title']}")
                    first_book = False
                else:
                    print(f"Te recomiendo {book['title']}")
                display(Image(book['coverimg'], width=300, height=600))
            
            return recommended_books
    
    return "No se confirmó ningún libro. Por favor, inténtalo de nuevo."

# %%
# Ask for user input
user_book = input("Introduce las primeras letras del título del libro que te gusta: ")
print(f"Tu busqueda ha sido: '{user_book}' y...")
recommendations = recommend_books(user_book, best, knn_models, processed_subsets, preprocessor)
# Out:
# Tu busqueda ha sido: 'prince' y...
# Este es tu libro: The Little Prince
# Te recomiendo Life of Pi
# Te recomiendo Memoirs of a Geisha
# Te recomiendo Sense and Sensibility
# Te recomiendo Bridget Jones's Diary
